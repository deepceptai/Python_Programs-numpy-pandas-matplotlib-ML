# %% [markdown]
# We can add a legend to a plot in Matplotlib using the plt.legend() method.

# %%
import numpy as np
import matplotlib.pyplot as plt

x = [1,2,4,8,10]
y = [1,12,14,18,20]
plt.plot(x, y, label='My Line')

plt.legend()
