# %% [markdown]
# plt.boxplot():- We can create a box plot in Matplotlib using the plt.boxplot() method.

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.normal(size=100)

plt.boxplot(data)
plt.show()
