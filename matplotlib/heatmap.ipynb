# %% [markdown]
#  plt.imshow() :- We can create a heat map in Matplotlib using the plt.imshow() method.

# %%
import matplotlib.pyplot as plt
import numpy as np

data = np.random.rand(5, 5)

plt.imshow(data, cmap='hot', interpolation='nearest')
plt.show()
