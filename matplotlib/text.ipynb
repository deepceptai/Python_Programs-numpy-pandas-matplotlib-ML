# %% [markdown]
#  You can add text to a plot in Matplotlib using the plt.text() method. For example:
#
# plt.text(x, y, 'My Text')

# %%
import matplotlib.pyplot 

matplotlib.pyplot.text(0.5, 0.5, "Hello World!") 
matplotlib.pyplot.savefig("out.png")
